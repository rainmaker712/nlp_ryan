# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from pprint import pprint

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans

import tensorflow as tf
from models.DenoisingAutoencoder import MaskingNoiseAutoencoder

# %% [markdown]
# # 0. Data Loading and processing
# 앞선 실험에서 TfidfVectorizer를 사용하는 것이 근소하게 성능이 더 좋았기 때문에, 여기서는 TfidfVectorizer만 사용하였음

# %%
# Load training set and test set
categories = ['alt.atheism', 'talk.religion.misc', 'comp.graphics', 'sci.space']
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'),
                                      categories=categories)
X = newsgroups.data
Y = newsgroups.target

# %%
# Declare two vectorizers
# count_vectorizer = CountVectorizer(min_df=40)
tfidf_vectorizer = TfidfVectorizer(min_df=40)

# %%
# Fitting vectorizers to the training set
# count_vectorizer = count_vectorizer.fit(X)
tfidf_vectorizer = tfidf_vectorizer.fit(X)

# %%
# Transform X_train and X_test using 2 vectorizers
# X_count = count_vectorizer.transform(X)
X_tfidf = tfidf_vectorizer.transform(X)

# %%
# Convert sparse matrix into dense matrix
X = X_tfidf.toarray()

# %%
n_samples = Y.shape[0]
print("Number of training points: ", n_samples)
# Out:
# Number of training points:  3387

# %%
dim_X = X.shape[1]
print("Dimension of X: %d" % dim_X)
# Out:
# Dimension of X: 1315

# %%
labels = np.unique(Y)
print("Labels: ", labels)
# Out:
# Labels:  [0 1 2 3]

# %% [markdown]
# # 1. k-means clustering with TF-IDF values

# %%
n_clusters_set = [3, 4, 5, 6]
names = []
models = []
results = []
silhouette_scores = []
mutual_scores = []
for n_clusters in n_clusters_set:
    # Add model name
    names.append('KMeans_k=%d' % n_clusters)
    # Call model
    model = KMeans(n_clusters=n_clusters, n_init=1, max_iter=100, verbose=1)
    # Fit the model
    model.fit(X)
    # Get cluster IDs
    result = model.predict(X)
    # Save model and result
    models.append(model)
    results.append(result)
    # Calculate silhouette score
    silhouette_scores.append(metrics.silhouette_score(X, result, metric = 'euclidean'))
    # Calculate mutual_information
    mutual_scores.append(metrics.adjusted_mutual_info_score(Y, result))
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 2842.41331031
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2793.4469902
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2779.92266914
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 2776.57731093
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 2775.48429994
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 2775.07344243
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 2774.9071878
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 2774.79891655
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 2774.75866898
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 2774.73974053
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 2774.72690887
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 2774.71435538
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 2774.70864551
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 2774.7052743
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 2774.7052743
# center shift 0.000000e+00 within tolerance 6.431008e-08
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 2825.7387421
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2779.25349354
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2764.87660017
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 2761.17268165
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 2759.69405547
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 2759.02610011
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 2758.62990902
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 2758.39683805
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 2758.21529235
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 2758.0761253
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 2757.88778242
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 2757.68120189
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 2757.46399126
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 2757.32361798
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 2757.24310123
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 2757.19316327
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 2757.1391497
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 2757.10433821
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 2757.07735775
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 2757.04706426
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 2757.03614827
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 2757.02588972
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 2757.02392698
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 2757.02199478
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 2757.02199478
# center shift 0.000000e+00 within tolerance 6.431008e-08
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 2818.56968197
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2767.93302754
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2752.60991217
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 2748.79156466
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 2747.80870495
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 2747.5756243
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 2747.47478581
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 2747.38629336
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 2747.34646423
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 2747.32783196
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 2747.3130024
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 2747.29867917
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 2747.29226959
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 2747.29226959
# center shift 0.000000e+00 within tolerance 6.431008e-08
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 2825.47800039
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2771.40668642
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2753.88394657
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 2749.48147279
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 2747.24750183
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 2744.58634325
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 2741.29092718
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 2737.90150125
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 2735.90210049
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 2735.39851437
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 2735.23476956
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 2735.1201689
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 2735.06522157
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 2735.01740904
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 2734.98547929
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 2734.94829066
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 2734.91639598
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 2734.87357743
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 2734.83016456
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 2734.79198379
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 2734.75534697
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 2734.74017395
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 2734.72554492
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 2734.7226701
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 2734.71967759
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 2734.71674171
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 2734.71674171
# center shift 0.000000e+00 within tolerance 6.431008e-08

# %%
silhouette_scores = pd.Series(silhouette_scores, index = names)
mutual_scores = pd.Series(mutual_scores, index = names)

# %%
print(silhouette_scores)
# Out:
# KMeans_k=3    0.005900
# KMeans_k=4    0.007762
# KMeans_k=5    0.009138
# KMeans_k=6   -0.004803
# dtype: float64

# %%
print(mutual_scores)
# Out:
# KMeans_k=3    0.069342
# KMeans_k=4    0.145373
# KMeans_k=5    0.139332
# KMeans_k=6    0.114837
# dtype: float64

# %%
cm = metrics.confusion_matrix(Y, results[1])
print(cm)
# Out:
# [[271 361   8 159]
#  [284  83 469 137]
#  [374 139  51 423]
#  [239 217   6 166]]

# %% [markdown]
# # 2. k-means clustering with embedded vectors by denoising autoencoder

# %%
# Parameters
transfer_function = tf.nn.sigmoid # tf.nn.relu, tf.nn.softplus, tf.nn.sigmoid, tf.nn.tanh
dropout_probability = 0.9
training_epochs = 100
batch_size = 32
display_step = 1

# %%
autoencoder = MaskingNoiseAutoencoder(n_input=dim_X,
                                      n_hidden=200,
                                      transfer_function=transfer_function,
                                      optimizer=tf.train.AdamOptimizer(learning_rate = 0.001),
                                      dropout_probability=dropout_probability,
                                      tied_weights=True)

# %%
def get_random_block_from_data(data, batch_size):
    start_index = np.random.randint(0, len(data) - batch_size)
    return data[start_index:(start_index + batch_size)]

# %%
for epoch in range(training_epochs):
    avg_cost = 0.
    total_batch = int(n_samples / batch_size)
    for i in range(total_batch):
        batch_xs = get_random_block_from_data(X, batch_size)
        
        # Fit training using batch data
        cost = autoencoder.partial_fit(batch_xs)
        # Compute average loss
        avg_cost += cost / n_samples * batch_size

    # Display logs per epoch step
    if epoch % display_step == 0:
        print("Epoch:", '%04d' % (epoch + 1), "\ttraining_cost=", "{:.9f}".format(avg_cost))
# Out:
# Epoch: 0001 	training_cost= 520.134605423
# Epoch: 0002 	training_cost= 36.746153380
# Epoch: 0003 	training_cost= 24.014486272
# Epoch: 0004 	training_cost= 19.450886125
# Epoch: 0005 	training_cost= 17.167007820
# Epoch: 0006 	training_cost= 16.048736644
# Epoch: 0007 	training_cost= 15.316067241
# Epoch: 0008 	training_cost= 14.680691751
# Epoch: 0009 	training_cost= 14.474720300
# Epoch: 0010 	training_cost= 14.256787922
# Epoch: 0011 	training_cost= 13.961486609
# Epoch: 0012 	training_cost= 13.920381675
# Epoch: 0013 	training_cost= 13.798801230
# Epoch: 0014 	training_cost= 13.716955527
# Epoch: 0015 	training_cost= 13.585108254
# Epoch: 0016 	training_cost= 13.518325071
# Epoch: 0017 	training_cost= 13.463409000
# Epoch: 0018 	training_cost= 13.472438068
# Epoch: 0019 	training_cost= 13.394249681
# Epoch: 0020 	training_cost= 13.316564478
# Epoch: 0021 	training_cost= 13.352491948
# Epoch: 0022 	training_cost= 13.290844431
# Epoch: 0023 	training_cost= 13.237605619
# Epoch: 0024 	training_cost= 13.354030964
# Epoch: 0025 	training_cost= 13.228593140
# Epoch: 0026 	training_cost= 13.218926023
# Epoch: 0027 	training_cost= 13.124978033
# Epoch: 0028 	training_cost= 13.117223180
# Epoch: 0029 	training_cost= 13.131973181
# Epoch: 0030 	training_cost= 13.182714939
# Epoch: 0031 	training_cost= 13.125220579
# Epoch: 0032 	training_cost= 13.067953006
# Epoch: 0033 	training_cost= 13.103925959
# Epoch: 0034 	training_cost= 13.054586802
# Epoch: 0035 	training_cost= 12.917697687
# Epoch: 0036 	training_cost= 13.013506294
# Epoch: 0037 	training_cost= 13.015755549
# Epoch: 0038 	training_cost= 12.992752755
# Epoch: 0039 	training_cost= 13.031069625
# Epoch: 0040 	training_cost= 13.038507714
# Epoch: 0041 	training_cost= 12.922674926
# Epoch: 0042 	training_cost= 13.040101260
# Epoch: 0043 	training_cost= 13.016425107
# Epoch: 0044 	training_cost= 12.942414592
# Epoch: 0045 	training_cost= 12.973473152
# Epoch: 0046 	training_cost= 12.918640218
# Epoch: 0047 	training_cost= 12.971500132
# Epoch: 0048 	training_cost= 12.923048967
# Epoch: 0049 	training_cost= 12.950112103
# Epoch: 0050 	training_cost= 12.883342850
# Epoch: 0051 	training_cost= 12.975250262
# Epoch: 0052 	training_cost= 12.923982740
# Epoch: 0053 	training_cost= 12.864584595
# Epoch: 0054 	training_cost= 12.839404259
# Epoch: 0055 	training_cost= 12.932194753
# Epoch: 0056 	training_cost= 12.840384435
# Epoch: 0057 	training_cost= 12.874857314
# Epoch: 0058 	training_cost= 12.715089846
# Epoch: 0059 	training_cost= 12.854350078
# Epoch: 0060 	training_cost= 12.855608814
# Epoch: 0061 	training_cost= 12.814921917
# Epoch: 0062 	training_cost= 12.738539095
# Epoch: 0063 	training_cost= 12.766177875
# Epoch: 0064 	training_cost= 12.820063269
# Epoch: 0065 	training_cost= 12.810560363
# Epoch: 0066 	training_cost= 12.767779674
# Epoch: 0067 	training_cost= 12.710707073
# Epoch: 0068 	training_cost= 12.773949010
# Epoch: 0069 	training_cost= 12.762505557
# Epoch: 0070 	training_cost= 12.719954710
# Epoch: 0071 	training_cost= 12.696597626
# Epoch: 0072 	training_cost= 12.609339148
# Epoch: 0073 	training_cost= 12.615833734
# Epoch: 0074 	training_cost= 12.647081680
# Epoch: 0075 	training_cost= 12.609474869
# Epoch: 0076 	training_cost= 12.613509370
# Epoch: 0077 	training_cost= 12.722827867
# Epoch: 0078 	training_cost= 12.563934389
# Epoch: 0079 	training_cost= 12.529500136
# Epoch: 0080 	training_cost= 12.558920559
# Epoch: 0081 	training_cost= 12.571973280
# Epoch: 0082 	training_cost= 12.542951937
# Epoch: 0083 	training_cost= 12.461474193
# Epoch: 0084 	training_cost= 12.398025679
# Epoch: 0085 	training_cost= 12.479265887
# Epoch: 0086 	training_cost= 12.530298107
# Epoch: 0087 	training_cost= 12.394870547
# Epoch: 0088 	training_cost= 12.301786258
# Epoch: 0089 	training_cost= 12.365766644
# Epoch: 0090 	training_cost= 12.194615966
# Epoch: 0091 	training_cost= 12.254481435
# Epoch: 0092 	training_cost= 12.260155109
# Epoch: 0093 	training_cost= 12.310421291
# Epoch: 0094 	training_cost= 12.084647977
# Epoch: 0095 	training_cost= 12.142437386
# Epoch: 0096 	training_cost= 12.209129250
# Epoch: 0097 	training_cost= 12.119489329
# Epoch: 0098 	training_cost= 11.975216150
# Epoch: 0099 	training_cost= 12.050112936
# Epoch: 0100 	training_cost= 12.013160510
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5b28cbfbe50f> in <module>()
#      14         print("Epoch:", '%04d' % (epoch + 1), "\ttraining_cost=", "{:.9f}".format(avg_cost))
#      15
# ---> 16 print("Total cost: " + str(autoencoder.calc_total_cost(X_test)))
#
# NameError: name 'X_test' is not defined

# %%
X_embedded = autoencoder.transform(X)

# %%
X_embedded.shape
# Out:
# (3387, 200)

# %%
n_clusters_set = [3, 4, 5, 6]
names = []
models = []
results = []
silhouette_scores = []
mutual_scores = []
for n_clusters in n_clusters_set:
    # Add model name
    names.append('KMeans_k=%d' % n_clusters)
    # Call model
    model = KMeans(n_clusters=n_clusters, n_init=1, max_iter=100, verbose=1)
    # Fit the model
    model.fit(X_embedded)
    # Get cluster IDs
    result = model.predict(X_embedded)
    # Save model and result
    models.append(model)
    results.append(result)
    # Calculate silhouette score
    silhouette_scores.append(metrics.silhouette_score(X, result, metric = 'euclidean'))
    # Calculate mutual_information
    mutual_scores.append(metrics.adjusted_mutual_info_score(Y, result))
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1270.73
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1251.9
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1247.92
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1246.55
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 1246.22
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 1246.14
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 1246.1
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 1246.1
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 1246.1
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 1246.1
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 1246.09
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 1246.09
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 1246.09
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 1246.09
# center shift 0.000000e+00 within tolerance 2.758520e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1253.81
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1191.8
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1172.72
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1161.71
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 1155.36
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 1150.49
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 1146.02
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 1141.72
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 1139.37
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 1138.36
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 1137.86
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 1137.53
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 1137.38
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 1137.27
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 1137.18
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 1137.14
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 1137.12
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 1137.1
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 1137.09
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 1137.08
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 1137.07
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 1137.07
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 1137.07
# center shift 0.000000e+00 within tolerance 2.758520e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1249.79
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1189.19
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1148.61
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1115.84
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 1101.11
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 1095.84
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 1092.88
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 1090.5
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 1088.68
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 1087.75
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 1087.38
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 1087.02
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 1086.69
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 1086.61
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 1086.58
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 1086.56
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 1086.54
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 1086.5
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 1086.47
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 1086.43
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 1086.39
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 1086.34
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 1086.28
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 1086.24
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 1086.21
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 1086.19
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 1086.17
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 1086.14
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 1086.12
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 1086.1
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 1086.09
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 1086.07
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 1086.06
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 1086.04
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 1086.02
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 1085.98
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 1085.94
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 1085.88
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 1085.79
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 1085.74
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 1085.72
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 1085.71
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 1085.7
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 1085.69
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 1085.67
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 1085.66
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 1085.64
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 1085.64
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 1085.64
# center shift 0.000000e+00 within tolerance 2.758520e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1125.15
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1052.66
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1035.95
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1023.28
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 1016.76
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 1014.5
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 1013.44
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 1012.73
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 1012.39
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 1012.21
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 1012.06
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 1011.93
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 1011.84
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 1011.8
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 1011.78
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 1011.77
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 1011.76
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 1011.75
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 1011.74
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 1011.74
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 1011.73
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 1011.73
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 1011.73
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 1011.72
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 1011.71
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 1011.7
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 1011.7
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 1011.7
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 1011.7
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 1011.7
# center shift 0.000000e+00 within tolerance 2.758520e-07

# %%
silhouette_scores = pd.Series(silhouette_scores, index = names)
mutual_scores = pd.Series(mutual_scores, index = names)

# %%
print(silhouette_scores)
# Out:
# KMeans_k=3    0.016752
# KMeans_k=4    0.000819
# KMeans_k=5   -0.002337
# KMeans_k=6   -0.019446
# dtype: float64

# %%
print(mutual_scores)
# Out:
# KMeans_k=3    0.135494
# KMeans_k=4    0.137630
# KMeans_k=5    0.153293
# KMeans_k=6    0.146659
# dtype: float64

# %%
cm = metrics.confusion_matrix(Y, results[2])
print(cm)
# Out:
# [[329   5 176 200  89]
#  [ 30 472 155  89 227]
#  [ 96  56 193 204 438]
#  [211   6 157 159  95]
#  [  0   0   0   0   0]]
